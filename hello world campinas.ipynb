# %% [markdown]
# ## Teste de código no Github

# %%
import pandas as pd
import numpy as np
import dotenv

print("Hello World")
# Out:
# Hello World

# %%
print('This is a test of the Python environment.')


senha = dotenv.get('senha')

# %%
print("This is a test of the Python environment.")
