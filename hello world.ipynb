# %% [markdown]
# ## Teste de código no Github

# %%
import pandas as pd
import numpy as np

print("Hello World")

# %%
print('This is a test of the Python environment.')

# %%
print("This is a test of the Python environment.")
